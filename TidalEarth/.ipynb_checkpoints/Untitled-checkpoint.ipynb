# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
names = ['Time', 'TMan','TUMan','TLMan','TCMB','TCore', 'HflowUMan', 'HflowMeltMan',
         'RadPowerMan' ,'RadPowerCore', 'RadPowerCrust',    'HflowCMB', 'HflowSecMan' ,
    'TDotMan', 'TDotCore', 'TJumpLMan', 'TJumpUMan', 'RIC', 'RayleighMan', 'ViscUMan', 'ViscLMan' ,
    'MeltMassFluxMan', 'FMeltUMan' ,    'MagMom', 'CoreBuoyTherm', 'CoreBuoyCompo' ,'CoreBuoyTotal', 'MagPauseRad' ,
    'BLUMan', 'BLLMan' ,  'K2', 'ImK2', 'SemiMajorAxis', 'Eccentricity' ,'ShmodUMan', 'MeanMotion', 'ViscUManArr',
     'ChiOC', 'ChiIC' ,'MassChiOC', 'MassChiIC', 'MassOC', 'MassIC' ,
    'RadPowerTotal', 'SurfEnFluxEqtide', 'PowerEqtide', 'TideLock', "TidalQ", "SurfEnFluxTotal", 'dShModRef', 'dViscRef']
data = pd.read_csv("tidalearth.b.forward", names=names, delim_whitespace=True)
datac = pd.read_csv("tidalearth.c.forward", names=names, delim_whitespace=True)

# %%
## calculate SMA

perb = 2.7299025 / 365.25 # days to years
smab = np.power(perb**2.0, 1/3.)
print (smab)

perc = 8.4575 / 365.25 # days to years
smac = np.power(perc**2.0, 1/3.)
print (smac)
# Out:
# 0.038227093115422356
# 0.08123961462255531

# %%
plt.plot(data['Time'], data['TMan'], label="Mantle")
plt.plot(data['Time'], data['TCore'], label="Core")
plt.ylabel('Temperature (K)')
plt.xlabel('Time (Gyr)')
plt.yscale("log")
s_yr = 3600.*24*365
# Out:
# <VPLOTFigure size 460.8x316.8 with 1 Axes>

# %%
colz = ['r', 'g', 'k']
filez = ["tidalearth.b.forward", "tidalearth.c.forward"]

for i, item in enumerate(filez):
    data = pd.read_csv(item, names=names, delim_whitespace=True)
    fig = plt.figure(1, figsize=(10,15))
    panel=1
    rows = 3
    cols = 2
    color = colz[i]
    plt.subplot(rows,cols,panel)
    plt.plot(data['Time'],data['TMan'],linestyle='-',color=color,label=r'$T_{M}$')
    plt.plot(data['Time'],data['TCore'],'--',color=color,label=r'$T_{C}$')
    plt.legend(loc='best',ncol=2,frameon=True)
    plt.ylabel('Temperature (K)')
    plt.xlabel('Time (Gyr)')
    plt.ylim(0,6e3)
    plt.xscale('log')
    panel += 1
    plt.subplot(rows,cols,panel)
    plt.plot(data['Time'],data['HflowUMan'],linestyle='-',color=color,label=r'$Q_{UMan}$')
    plt.plot(data['Time'],data['HflowMeltMan'],linestyle=(0, (3, 5, 1, 5, 1, 5)),color=color,label=r'$Q_{Melt,Man}$')
    plt.plot(data['Time'],data['HflowCMB'],linestyle='--',color=color,label=r'$Q_{CMB}$')
    plt.plot(data['Time'],data['RadPowerMan'],linestyle=(0, (1, 5)),color=color,label=r'$Q_{Rad,Man}$')
    plt.plot(data['Time'],data['PowerEqtide'],'-.',color=color,label=r'$Q_{Tide}$')
    plt.yscale('log'); plt.xscale('log')
    plt.legend(loc='upper right',frameon=True,ncol=2,columnspacing=1)
    plt.ylabel('Power (TW)')
    plt.xlabel('Time (Gyr)')
    ymax=1e10
    plt.ylim(1e-4,ymax)
    panel += 1
    plt.subplot(rows,cols,panel)
    plt.plot(data['Time'],data['SemiMajorAxis'],color=color,label='$a_0$=%.2f'%data['SemiMajorAxis'].values[0])
    plt.ylabel(r'Semi-Major Axis (AU)')
    plt.xlabel('Time (Gyr)')
    plt.ylim(0,0.10)
    plt.xscale('log')
    plt.legend(frameon=True,loc='upper left')
    panel += 1
    plt.subplot(rows,cols,panel)
    plt.loglog(data['Time'],data['Eccentricity'],color=color,label='ecc')
    plt.ylabel(r'Eccentricity')
    plt.xlabel('Time (Gyr)')
    plt.ylim(1e-5,1)
    plt.yscale('log'); plt.xscale('log')
    panel += 1
    plt.subplot(rows,cols,panel)
    plt.plot(data['Time'],data['MagMom'],color=color,label='MagMom')
    plt.plot(data['Time'],data['RIC']/3481,color=color,linestyle='--')
    plt.ylim(0,1.5)
    plt.ylabel('Mag. Mom., R$_{ic}$ ($\oplus$ Units)')
    plt.xlabel('Time (Gyr)')
    plt.xscale('log')
    panel += 1
    plt.subplot(rows,cols,panel)
    plt.plot(data['Time'],data['MeltMassFluxMan']*s_yr,color=color)
    plt.ylabel(r'Melt Mass Flux Mantle (kg$/$yr)')
    plt.xlabel('Time (Gyr)')
    plt.ylim(1e12,1e18)
    plt.yscale('log'); plt.xscale('log')
plt.savefig("/Users/jcbecker/Downloads/temp.png", dpi=150, bbox_inches = "tight")

# %% [markdown]
# Set up parameter sweeps: https://virtualplanetarylaboratory.github.io/vplanet/parametersweep.html
#
# Relevant parameters:
#
# dEcc (initial orbital eccentricity)
#
#
# I think we want to make plots in terms of tidal Q
#
# After it is run, run in terminal:
# > bigplanet -c 2 bpl.in

# %%
import bigplanet as bp
import vplot as vp
import glob

# %%
folders = glob.glob("ParameterSweep/test*")
folders
infofile = pd.read_csv("ParameterSweep/grid_list.dat", delim_whitespace = True)
infofile[:5]
# Out:
#            trial  c/dMass  c/dActViscMan
# 0  cmass0_cvisc0      1.0  270000.000000
# 1  cmass0_cvisc1      1.0  284444.444444
# 2  cmass0_cvisc2      1.0  298888.888889
# 3  cmass0_cvisc3      1.0  313333.333333
# 4  cmass0_cvisc4      1.0  327777.777778

# %%
idx = (infofile['b/dEcc'] == 0.01) & (infofile['c/dEcc'] == 0.01) & (infofile['b/dMass'] == -1.0) & (infofile['c/dMass'] == -2.3)  
item = infofile.loc[idx]['trial'].values[0]
datab = pd.read_csv("ParameterSweep/test_" + item + "/tidalearth.b.forward", names=names, delim_whitespace=True)
datac = pd.read_csv("ParameterSweep/test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)


plt.plot(datab['Time'], datab['SurfEnFluxTotal'], label="Mantle")
plt.plot(datac['Time'], datac['SurfEnFluxTotal'], label="Mantle")
plt.ylabel('Tidal Q')
plt.xlabel('Time (Gyr)')
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'b/dEcc'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-c2cae1b4bf52> in <module>
# ...

# %%
plt.plot(datab['Time'], datab['MagMom'], label="Mantle")
plt.plot(datac['Time'], datac['MagMom'], label="Mantle")
plt.ylabel('Magnetic Moment')
plt.xlabel('Time (Gyr)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0d5214b3a172> in <module>
# ----> 1 plt.plot(datab['Time'], datab['MagMom'], label="Mantle")
#       2 plt.plot(datac['Time'], datac['MagMom'], label="Mantle")
#       3 plt.ylabel('Magnetic Moment')
#       4 plt.xlabel('Time (Gyr)')
#       5
#
# NameError: name 'datab' is not defined

# %%
summary_list = pd.DataFrame()
for item in infofile['trial'].unique():
    try:
        names = ['Time', 'TMan','TUMan','TLMan','TCMB','TCore', 'HflowUMan', 'HflowMeltMan',
             'RadPowerMan' ,'RadPowerCore', 'RadPowerCrust',    'HflowCMB', 'HflowSecMan' ,
        'TDotMan', 'TDotCore', 'TJumpLMan', 'TJumpUMan', 'RIC', 'RayleighMan', 'ViscUMan', 'ViscLMan' ,
        'MeltMassFluxMan', 'FMeltUMan' ,    'MagMom', 'CoreBuoyTherm', 'CoreBuoyCompo' ,'CoreBuoyTotal', 'MagPauseRad' ,
        'BLUMan', 'BLLMan' ,  'K2', 'ImK2', 'SemiMajorAxis', 'Eccentricity' ,'ShmodUMan', 'MeanMotion', 'ViscUManArr',
         'ChiOC', 'ChiIC' ,'MassChiOC', 'MassChiIC', 'MassOC', 'MassIC' ,
        'RadPowerTotal', 'SurfEnFluxEqtide', 'PowerEqtide', 'TideLock', "TidalQ", "SurfEnFluxTotal"]
        idx = (infofile['trial'] == item)
        datab = pd.read_csv("ParameterSweep/test_" + item + "/tidalearth.b.forward", names=names, delim_whitespace=True)
        datac = pd.read_csv("ParameterSweep/test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
        summary_list = summary_list.append({"directory": item,
                                            "ecc_c": infofile.loc[idx]['c/dEcc'].values[0],
                                             "mass_c": infofile.loc[idx]['c/dMass'].values[0],
                                             "ecc_b": infofile.loc[idx]['b/dEcc'].values[0],
                                             "mass_b": infofile.loc[idx]['b/dMass'].values[0],
                                            "Qf_b":datab['TidalQ'].values[0],"Ecc_b":datab['Eccentricity'].values[0],
                                            "Qi_b":datab['TidalQ'].values[-1], "ShmodUMan_b":datab['ShmodUMan'].values[-1],
                                            "PowerEqtidef_b":datab['PowerEqtide'].values[-1], "SurfEnFluxTotalf_b":datab['SurfEnFluxTotal'].values[-1],
                                           "Qf_c":datac['TidalQ'].values[0],"Ecc_c":datac['Eccentricity'].values[0],
                                            "Qi_c":datac['TidalQ'].values[-1], "ShmodUMan_c":datac['ShmodUMan'].values[-1],
                                            "PowerEqtidef_c":datac['PowerEqtide'].values[-1], "SurfEnFluxTotalf_c":datac['SurfEnFluxTotal'].values[-1],
                                            "MeltMassFluxManf_c": datac['PowerEqtide'].values[-1],
                                           }, ignore_index = True)
    except FileNotFoundError:
        pass
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'c/dEcc'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-75cddb6c6b8d> in <module>
# ...

# %%
summary_list[:5]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
plt.scatter(summary_list['ecc_c']  + np.linspace(0,0.03, len(summary_list['ecc_c'])), -1 * summary_list['mass_c'],  c= summary_list['SurfEnFluxTotalf_b'], )
plt.colorbar(label = "Surface Flux (W/meter^2)")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.xlabel("Initial Eccentricity", fontsize = 15)
plt.ylabel("Planet Mass", fontsize = 15)
plt.figure()
plt.scatter(summary_list['ecc_c'] + np.linspace(0,0.03, len(summary_list['ecc_c'])) , -1 * summary_list['mass_c'],  c= summary_list['PowerEqtidef_c'], )
plt.colorbar(label = "Tidal Power")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.xlabel("Initial Eccentricity", fontsize = 15)
plt.ylabel("Planet Mass", fontsize = 15)
# Out:
# Text(0, 0.5, 'Planet Mass')
# <VPLOTFigure size 460.8x316.8 with 2 Axes>
# <VPLOTFigure size 460.8x316.8 with 2 Axes>

# %%
data.columns
# Out:
# Index(['Time', 'TMan', 'TUMan', 'TLMan', 'TCMB', 'TCore', 'HflowUMan',
#        'HflowMeltMan', 'RadPowerMan', 'RadPowerCore', 'RadPowerCrust',
#        'HflowCMB', 'HflowSecMan', 'TDotMan', 'TDotCore', 'TJumpLMan',
#        'TJumpUMan', 'RIC', 'RayleighMan', 'ViscUMan', 'ViscLMan',
#        'MeltMassFluxMan', 'FMeltUMan', 'MagMom', 'CoreBuoyTherm',
#        'CoreBuoyCompo', 'CoreBuoyTotal', 'MagPauseRad', 'BLUMan', 'BLLMan',
#        'K2', 'ImK2', 'SemiMajorAxis', 'Eccentricity', 'ShmodUMan',
#        'MeanMotion', 'ViscUManArr', 'ChiOC', 'ChiIC', 'MassChiOC', 'MassChiIC',
#        'MassOC', 'MassIC', 'RadPowerTotal', 'SurfEnFluxEqtide', 'PowerEqtide',
#        'TideLock', 'TidalQ'],
#       dtype='object')

# %%
## let's look at one planet at a time
infofile = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarthSingle/ParameterSweep/grid_list.dat", delim_whitespace = True)

summary_list = pd.DataFrame()
for item in infofile['trial'].unique():
    try:
        names = ['Time', 'TMan','TUMan','TLMan','TCMB','TCore', 'HflowUMan', 'HflowMeltMan',
             'RadPowerMan' ,'RadPowerCore', 'RadPowerCrust',    'HflowCMB', 'HflowSecMan' ,
        'TDotMan', 'TDotCore', 'TJumpLMan', 'TJumpUMan', 'RIC', 'RayleighMan', 'ViscUMan', 'ViscLMan' ,
        'MeltMassFluxMan', 'FMeltUMan' ,    'MagMom', 'CoreBuoyTherm', 'CoreBuoyCompo' ,'CoreBuoyTotal', 'MagPauseRad' ,
        'BLUMan', 'BLLMan' ,  'K2', 'ImK2', 'SemiMajorAxis', 'Eccentricity' ,'ShmodUMan', 'MeanMotion', 'ViscUManArr',
         'ChiOC', 'ChiIC' ,'MassChiOC', 'MassChiIC', 'MassOC', 'MassIC' ,
        'RadPowerTotal', 'SurfEnFluxEqtide', 'PowerEqtide', 'TideLock', "TidalQ", "SurfEnFluxTotal"]
        idx = (infofile['trial'] == item)
        datab = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarthSingle/ParameterSweep/test_" + item + "/tidalearth.b.forward", names=names, delim_whitespace=True)
        datac = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarthSingle/ParameterSweep/test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
        summary_list = summary_list.append({"directory": item,
                                            "ecc_c": infofile.loc[idx]['c/dEcc'].values[0],
                                             "mass_c": infofile.loc[idx]['c/dMass'].values[0],
                                           "Qi_c":datac['TidalQ'].values[0],"Ecc_c":datac['Eccentricity'].values[0],
                                            "Qf_c":datac['TidalQ'].values[-1], "ShmodUMan_c":datac['ShmodUMan'].values[-1],
                                            "PowerEqtidef_c":datac['PowerEqtide'].values[-1], "SurfEnFluxTotalf_c":datac['SurfEnFluxTotal'].values[-1],
                                            "MeltMassFluxManf_c": datac['MeltMassFluxMan'].values[-1],
                                           }, ignore_index = True)
    except FileNotFoundError:
        pass

# %%
summary_list
# Out:
#        Ecc_c  MeltMassFluxManf_c  PowerEqtidef_c      Qf_c        Qi_c  \
# 0   0.010000                 0.0    1.141200e-02  6.003930  108.727898
# 1   0.010000                 0.0    4.274200e-02  6.003951  108.606569
# 2   0.010000                 0.0    7.989600e-02  6.003972  108.477108
# 3   0.010000                 0.0    1.150910e-01  6.003993  108.361212
# 4   0.010000                 0.0    1.461940e-01  6.004014  108.262351
# 5   0.010000                 0.0    1.730940e-01  6.004036  108.178912
# 6   0.010000                 0.0    1.962630e-01  6.004057  108.108329
# 7   0.010000                 0.0    2.162750e-01  6.004078  108.048217
# 8   0.010000                 0.0    2.336550e-01  6.004099  107.996601
# 9   0.010000                 0.0    2.488470e-01  6.004121  107.951909
# 10  0.108889                 0.0    1.013404e+00  6.003930  105.922881
# 11  0.108889                 0.0    3.863529e+00  6.003951   98.011967
# ...

# %%
plt.scatter(summary_list['ecc_c'], -1 * summary_list['mass_c'], marker = "s", s = 120,  c= summary_list['SurfEnFluxTotalf_c'], )
plt.colorbar(label = "Surface Flux (W/meter^2)")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.xlabel("Initial Eccentricity", fontsize = 15)
plt.ylabel("Planet Mass", fontsize = 15)
plt.title("Planet c", fontsize = 15)
plt.figure()
plt.scatter(summary_list['ecc_c'] , -1 * summary_list['mass_c'],  marker = "s", s = 120, c= summary_list['PowerEqtidef_c'], )
plt.colorbar(label = "Tidal Power")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.xlabel("Initial Eccentricity", fontsize = 15)
plt.ylabel("Planet Mass", fontsize = 15)
plt.title("Planet c", fontsize = 15)

plt.figure()
plt.scatter(summary_list['ecc_c']  , -1 * summary_list['mass_c'], marker = "s", s = 120,  c= summary_list['MeltMassFluxManf_c'], )
plt.colorbar(label = "Mantle mass flux (kg/s)")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.xlabel("Initial Eccentricity", fontsize = 15)
plt.ylabel("Planet Mass", fontsize = 15)
plt.title("Planet c", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Planet c')
# <VPLOTFigure size 460.8x316.8 with 2 Axes>
# <VPLOTFigure size 460.8x316.8 with 2 Axes>
# <VPLOTFigure size 460.8x316.8 with 2 Axes>

# %%
ecclist = summary_list['ecc_c'].unique()
print(ecclist)
masslist = infofile['c/dMass'].unique()
print(masslist)
# Out:
# [0.01     0.108889 0.207778 0.306667 0.405556 0.504444 0.603333 0.702222
#  0.801111 0.9     ]
# [-0.5      -0.777778 -1.055556 -1.333333 -1.611111 -1.888889 -2.166667
#  -2.444444 -2.722222 -3.      ]

# %%
idx = (infofile['c/dEcc'] == ecclist[0]) & (infofile['c/dMass'] == masslist[2])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarthSingle/ParameterSweep/test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac['MeltMassFluxMan'], linewidth = 3, color = 'DarkRed', label="Quiet Mantle")

idx = (infofile['c/dEcc'] == ecclist[5]) & (infofile['c/dMass'] == masslist[-1])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarthSingle/ParameterSweep/test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac['MeltMassFluxMan'], linewidth = 3, label="Active Mantle")

plt.legend()
plt.ylabel('Mantle Mass Flux (kg/s)')
plt.xlabel('Time (Gyr)')
plt.yscale("log")
# Out:
# <VPLOTFigure size 460.8x316.8 with 1 Axes>

# %%
idx = (infofile['c/dEcc'] == ecclist[0]) & (infofile['c/dMass'] == masslist[2])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarthSingle/ParameterSweep/test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac['HflowUMan'], linewidth = 3, color = 'DarkRed', label="Quiet Mantle")
plt.plot(datac['Time'], datac['PowerEqtide'], linewidth = 3, linestyle="--", color = 'DarkRed', label="Quiet Mantle")
plt.plot(datac['Time'], datac['RadPowerTotal'], linewidth = 3, linestyle="-.", color = 'red', label="rad power")
plt.legend()
plt.ylabel('HflowUMan')
plt.xlabel('Time (Gyr)')
plt.yscale("log")
plt.figure()
print(datac['RadPowerTotal'].values[-1], masslist[2])
idx = (infofile['c/dEcc'] == ecclist[5]) & (infofile['c/dMass'] == masslist[2])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarthSingle/ParameterSweep/test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac['HflowUMan'], linewidth = 3, label="Active Mantle")
plt.plot(datac['Time'], datac['PowerEqtide'], linewidth = 3, linestyle="--", color = 'blue', label="Active Mantle")
plt.plot(datac['Time'], datac['RadPowerTotal'], linewidth = 3, linestyle="-.", color = 'blue', label="Active Mantle")
print(datac['RadPowerTotal'].values[-1], masslist[-1])
plt.legend()
plt.ylabel('HflowUMan')
plt.xlabel('Time (Gyr)')
plt.yscale("log")
# Out:
# 14.523379 -1.055556
# 14.523379 -3.0
# <VPLOTFigure size 460.8x316.8 with 1 Axes>
# <VPLOTFigure size 460.8x316.8 with 1 Axes>

# %%
idx = (infofile['c/dEcc'] == ecclist[0]) & (infofile['c/dMass'] == masslist[2])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarthSingle/ParameterSweep/test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac['MagMom'], linewidth = 3, color = 'DarkRed', label="Quiet Mantle")
plt.legend()
plt.ylabel('HflowUMan')
plt.xlabel('Time (Gyr)')
plt.yscale("log")

idx = (infofile['c/dEcc'] == ecclist[5]) & (infofile['c/dMass'] == masslist[2])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarthSingle/ParameterSweep/test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac['MagMom'], linewidth = 3, label="Active Mantle")
print(datac['RadPowerTotal'].values[-1], masslist[-1])
plt.legend()
plt.ylabel('MagMom')
plt.xlabel('Time (Gyr)')
plt.yscale("log")
# Out:
# 14.523379 -3.0
# <VPLOTFigure size 460.8x316.8 with 1 Axes>

# %%
idx = (infofile['c/dEcc'] == ecclist[0]) & (infofile['c/dMass'] == masslist[2])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarthSingle/ParameterSweep/test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac['MagMom'], linewidth = 3, color = 'DarkRed', label="Quiet Mantle")

idx = (infofile['c/dEcc'] == ecclist[5]) & (infofile['c/dMass'] == masslist[-1])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarthSingle/ParameterSweep/test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac['MagMom'], linewidth = 3, label="Active Mantle")

plt.legend()
plt.ylabel('Mag Moment')
plt.xlabel('Time (Gyr)')
plt.ylim(0.6, 1.4)
# Out:
# (0.6, 1.4)
# <VPLOTFigure size 460.8x316.8 with 1 Axes>

# %%
idx = (infofile['c/dEcc'] == ecclist[0]) & (infofile['c/dMass'] == masslist[2])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarthSingle/ParameterSweep/test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac['Eccentricity'], linewidth = 3, color = 'DarkRed', label="Quiet Mantle")

idx = (infofile['c/dEcc'] == ecclist[5]) & (infofile['c/dMass'] == masslist[-1])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarthSingle/ParameterSweep/test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac['Eccentricity'], linewidth = 3, label="Active Mantle")

plt.legend()
plt.ylabel('Eccentricity')
plt.xlabel('Time (Gyr)')
plt.yscale("log")
# Out:
# <VPLOTFigure size 460.8x316.8 with 1 Axes>

# %%
## let's look at one planet at a time
infofile = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarth/ParameterSweep/grid_list.dat", delim_whitespace = True)

summary_list = pd.DataFrame()
for item in infofile['trial'].unique():
    try:
        names = ['Time', 'TMan','TUMan','TLMan','TCMB','TCore', 'HflowUMan', 'HflowMeltMan',
             'RadPowerMan' ,'RadPowerCore', 'RadPowerCrust',    'HflowCMB', 'HflowSecMan' ,
        'TDotMan', 'TDotCore', 'TJumpLMan', 'TJumpUMan', 'RIC', 'RayleighMan', 'ViscUMan', 'ViscLMan' ,
        'MeltMassFluxMan', 'FMeltUMan' ,    'MagMom', 'CoreBuoyTherm', 'CoreBuoyCompo' ,'CoreBuoyTotal', 'MagPauseRad' ,
        'BLUMan', 'BLLMan' ,  'K2', 'ImK2', 'SemiMajorAxis', 'Eccentricity' ,'ShmodUMan', 'MeanMotion', 'ViscUManArr',
         'ChiOC', 'ChiIC' ,'MassChiOC', 'MassChiIC', 'MassOC', 'MassIC' ,
        'RadPowerTotal', 'SurfEnFluxEqtide', 'PowerEqtide', 'TideLock', "TidalQ", "SurfEnFluxTotal"]
        idx = (infofile['trial'] == item)
        datac = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarth/ParameterSweep/test_" + item + "/tidalearth.b.forward", names=names, delim_whitespace=True)
        summary_list = summary_list.append({"directory": item,
                                            "ecc_c": infofile.loc[idx]['c/dVisc'].values[0],
                                             "mass_c": infofile.loc[idx]['c/dMass'].values[0],
                                           "Qf_c":datac['TidalQ'].values[0],"Ecc_c":datac['Eccentricity'].values[0],
                                            "Qi_c":datac['TidalQ'].values[-1], "ShmodUMan_c":datac['ShmodUMan'].values[-1],
                                            "PowerEqtidef_c":datac['PowerEqtide'].values[-1], "SurfEnFluxTotalf_c":datac['SurfEnFluxTotal'].values[-1],
                                            "MeltMassFluxManf_c": datac['MeltMassFluxMan'].values[-1],
                                           }, ignore_index = True)
    except FileNotFoundError:
        pass
        
        
plt.scatter(summary_list['ecc_c'], -1 * summary_list['mass_c'], marker = "s", s = 120,  c= summary_list['SurfEnFluxTotalf_c'], )
plt.colorbar(label = "Surface Flux (W/meter^2)")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.xlabel("Initial Eccentricity", fontsize = 15)
plt.ylabel("Planet Mass", fontsize = 15)
plt.title("Planet b", fontsize = 15)
plt.figure()
plt.scatter(summary_list['ecc_c'] , -1 * summary_list['mass_c'],  marker = "s", s = 120, c= summary_list['PowerEqtidef_c'], )
plt.colorbar(label = "Tidal Power")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.xlabel("Initial Eccentricity", fontsize = 15)
plt.ylabel("Planet Mass", fontsize = 15)
plt.title("Planet c", fontsize = 15)

plt.figure()
plt.scatter(summary_list['ecc_c']  , -1 * summary_list['mass_c'], marker = "s", s = 120,  c= summary_list['MeltMassFluxManf_c'], )
plt.colorbar(label = "Mantle mass flux (kg/s)")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.xlabel("Initial Eccentricity", fontsize = 15)
plt.ylabel("Planet Mass", fontsize = 15)
plt.title("Planet b", fontsize = 15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ecc_c'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-88f8b24e3e64> in <module>
#      26
#      27
# ...

# %%
ecclist = summary_list['ecc_c'].unique()
print(ecclist)
masslist = infofile['b/dMass'].unique()
print(masslist)
idx = (infofile['b/dEcc'] == ecclist[0]) & (infofile['b/dMass'] == masslist[2])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarth/ParameterSweep/test_" + item + "/tidalearth.b.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac['TidalQ'], linewidth = 3, color = 'DarkRed', label="Quiet Mantle")

idx = (infofile['b/dEcc'] == ecclist[5]) & (infofile['b/dMass'] == masslist[-1])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarth/ParameterSweep/test_" + item + "/tidalearth.b.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac['TidalQ'], linewidth = 3, label="Active Mantle")

plt.legend()
plt.ylabel('Tidal Q')
plt.xlabel('Time (Gyr)')
plt.yscale("log")
# Out:
# [0.01     0.064444 0.118889 0.173333 0.227778 0.282222 0.336667 0.391111
#  0.445556 0.5     ]
# [-1.       -1.144444 -1.288889 -1.433333 -1.577778 -1.722222 -1.866667
#  -2.011111 -2.155556 -2.3     ]
# <VPLOTFigure size 460.8x316.8 with 1 Axes>

# %% [markdown]
# ## now, we set the planet mass.
#
# We will be changing the eccentricity and the viscosity activation energy. (this should change the tidal Q without needing to change the mass)

# %%
## let's look at one planet at a time
prefactor = "/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarth/ParameterSweep/"
infofile = pd.read_csv(prefactor + "grid_list.dat", delim_whitespace = True)

summary_list = pd.DataFrame()
for item in infofile['trial'].unique():
    try:
        names = ['Time', 'TMan','TUMan','TLMan','TCMB','TCore', 'HflowUMan', 'HflowMeltMan',
             'RadPowerMan' ,'RadPowerCore', 'RadPowerCrust',    'HflowCMB', 'HflowSecMan' ,
        'TDotMan', 'TDotCore', 'TJumpLMan', 'TJumpUMan', 'RIC', 'RayleighMan', 'ViscUMan', 'ViscLMan' ,
        'MeltMassFluxMan', 'FMeltUMan' ,    'MagMom', 'CoreBuoyTherm', 'CoreBuoyCompo' ,'CoreBuoyTotal', 'MagPauseRad' ,
        'BLUMan', 'BLLMan' ,  'K2', 'ImK2', 'SemiMajorAxis', 'Eccentricity' ,'ShmodUMan', 'MeanMotion', 'ViscUManArr',
         'ChiOC', 'ChiIC' ,'MassChiOC', 'MassChiIC', 'MassOC', 'MassIC' ,
        'RadPowerTotal', 'SurfEnFluxEqtide', 'PowerEqtide', 'TideLock', "TidalQ", "SurfEnFluxTotal"]
        idx = (infofile['trial'] == item)
        #datab = pd.read_csv("/Users/jcbecker/Documents/GitHub/LP890-9/TidalEarthSingle/ParameterSweep/test_" + item + "/tidalearth.b.forward", names=names, delim_whitespace=True)
        datac = pd.read_csv(prefactor + "test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
        summary_list = summary_list.append({"directory": item,
                                            "ecc_c": infofile.loc[idx]['c/dMass'].values[0],
                                             "A_c": infofile.loc[idx]['c/dActViscMan'].values[0],
                                           "Qi_c":datac['TidalQ'].values[0],"Ecc_c":datac['Eccentricity'].values[0],
                                            "Qf_c":datac['TidalQ'].values[-1], "ShmodUMan_c":datac['ShmodUMan'].values[-1],
                                            "PowerEqtidef_c":datac['PowerEqtide'].values[-1], "SurfEnFluxTotalf_c":datac['SurfEnFluxTotal'].values[-1],
                                            "MeltMassFluxManf_c": datac['MeltMassFluxMan'].values[-1],
                                            "MagMomf_c": datac['MagMom'].values[-1],
                                            "Eccf_c":datac['Eccentricity'].values[-1],
                                             "RadPowerf_c":datac['RadPowerTotal'].values[-1],
                                             "RICf_c":datac['RIC'].values[-1],
                                             "TManf_c":datac['TMan'].values[-1],
                                            "TCoref_c":datac['TCore'].values[-1]
                                           }, ignore_index = True)
    except FileNotFoundError:
        pass

# %%
infofile[:5]
# Out:
#            trial  c/dMass  c/dActViscMan
# 0  cmass0_cvisc0      1.0  270000.000000
# 1  cmass0_cvisc1      1.0  284444.444444
# 2  cmass0_cvisc2      1.0  298888.888889
# 3  cmass0_cvisc3      1.0  313333.333333
# 4  cmass0_cvisc4      1.0  327777.777778

# %%
summary_list
# Out:
#               A_c  Ecc_c    Eccf_c  MagMomf_c  MeltMassFluxManf_c  \
# 0   270000.000000    0.4  0.397954   0.000000                 0.0
# 1   284444.444444    0.4  0.397954   0.546963                 0.0
# 2   298888.888889    0.4  0.397954   0.830154                 0.0
# 3   313333.333333    0.4  0.397954   0.887926                 0.0
# 4   327777.777778    0.4  0.397954   0.864904                 0.0
# 5   342222.222222    0.4  0.397954   0.764999            122804.0
# 6   356666.666667    0.4  0.397954   0.367498            738015.6
# 7   371111.111111    0.4  0.397954   0.000000           1243501.0
# 8   385555.555556    0.4  0.397954   0.000000           1610923.0
# 9   400000.000000    0.4  0.397954   0.000000           1862750.0
# 10  270000.000000    0.4  0.396971   0.000000                 0.0
# 11  284444.444444    0.4  0.396971   0.546949                 0.0
# 12  298888.888889    0.4  0.396971   0.830148                 0.0
# ...

# %%
plt.plot(summary_list['A_c'], np.log10(summary_list['Qi_c']),'.')
# Out:
# <VPLOTFigure size 460.8x316.8 with 1 Axes>

# %%
fig, ax1 = plt.subplots()
yparam = 'PowerEqtidef_c'

plt.scatter(summary_list['ecc_c']  , summary_list['A_c'], marker = "s", s = 120,  c= np.log10(summary_list[yparam]), )
plt.colorbar(label = "log10" + yparam, pad = 0.15)
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
ax1.set_xlabel("Planet Mass", fontsize = 15)
ax1.set_ylabel("A_c", fontsize = 15)
plt.title("Planet c", fontsize = 15)
ax2 = ax1.twinx()
ax2.scatter(summary_list['ecc_c'] , np.log10(summary_list['Qi_c']), marker = "s", s = 10,  c= np.log10(summary_list['Qi_c']),alpha=0 )
ax2.set_ylabel("log$_{10}$(Q)", fontsize = 15)
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
ax2.set_xlabel("Planet Mass", fontsize = 15)
# Out:
# Text(0.5, 0, 'Planet Mass')
# <VPLOTFigure size 460.8x316.8 with 3 Axes>

# %% [markdown]
# # plt.figure()
# plt.scatter(summary_list['ecc_c']  , summary_list['A_c'], marker = "s", s = 120,  c= summary_list['MagMomf_c'], )
# plt.colorbar(label = "Mantle mass flux (kg/s)")
# plt.xticks(fontsize = 13)
# plt.yticks(fontsize = 13)
# plt.xlabel("Initial Eccentricity", fontsize = 15)
# plt.ylabel("A_c", fontsize = 15)
# plt.title("Planet c", fontsize = 15)

# %%
plt.hist(summary_list['MagMomf_c'])
# Out:
# (array([40.,  0., 10.,  0.,  0., 20.,  0.,  0.,  0., 30.]),
#  array([0.       , 0.0888434, 0.1776868, 0.2665302, 0.3553736, 0.444217 ,
#         0.5330604, 0.6219038, 0.7107472, 0.7995906, 0.888434 ]),
#  <BarContainer object of 10 artists>)
# <VPLOTFigure size 460.8x316.8 with 1 Axes>

# %%
ecclist = summary_list['ecc_c'].unique()
print(ecclist)
masslist = infofile['c/dActViscMan'].unique()
print(masslist)
yparam = 'Eccentricity'
idx = (infofile['c/dEcc'] == ecclist[-2]) & (infofile['c/dActViscMan'] == masslist[1])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv(prefactor + "test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac[yparam], linewidth = 3, color = 'DarkRed', label="Quiet Mantle")

idx = (infofile['c/dEcc'] == ecclist[0]) & (infofile['c/dActViscMan'] == masslist[-1])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv(prefactor + "test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac[yparam], linewidth = 3, label="Active Mantle")

plt.legend()
plt.ylabel(yparam)
plt.xlabel('Time (Gyr)')
plt.yscale("log")
# Out:
# [0.01     0.064444 0.118889 0.173333 0.227778 0.282222 0.336667 0.391111
#  0.445556 0.5     ]
# [250000.       266666.666667 283333.333333 300000.       316666.666667
#  333333.333333 350000.       366666.666667 383333.333333 400000.      ]
# <VPLOTFigure size 460.8x316.8 with 1 Axes>

# %%
ecclist = summary_list['ecc_c'].unique()
print(ecclist)
masslist = infofile['c/dActViscMan'].unique()
print(masslist)
yparam = 'MagMom'
idx = (infofile['c/dEcc'] == ecclist[0]) & (infofile['c/dActViscMan'] == masslist[-1])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv(prefactor + "test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac[yparam], linewidth = 3, color = 'DarkRed', label="Quiet Mantle")

idx = (infofile['c/dEcc'] == ecclist[0]) & (infofile['c/dActViscMan'] == masslist[-1])  
item = infofile.loc[idx]['trial'].values[0]
datac = pd.read_csv(prefactor + "test_" + item + "/tidalearth.c.forward", names=names, delim_whitespace=True)
plt.plot(datac['Time'], datac[yparam], linewidth = 3, label="Active Mantle")

plt.legend()
plt.ylabel(yparam)
plt.xlabel('Time (Gyr)')
plt.yscale("log")

plt.figure(figsize=(8,12))
colz = ['r', 'g', 'k']
filez = [prefactor + "test_" + item + "/tidalearth.c.forward"]

for i, item in enumerate(filez):
    data = pd.read_csv(item, names=names, delim_whitespace=True)
    fig = plt.figure(figsize=(8,12))
    panel=1
    rows = 3
    cols = 2
    color = colz[i]
    plt.subplot(rows,cols,panel)
    plt.plot(data['Time'],data['TMan'],linestyle='-',color=color,label=r'$T_{M}$')
    plt.plot(data['Time'],data['TCore'],'--',color=color,label=r'$T_{C}$')
    plt.legend(loc='best',ncol=2,frameon=True)
    plt.ylabel('Temperature (K)')
    plt.xlabel('Time (Gyr)')
    plt.ylim(0,6e3)
    plt.xscale('log')
    panel += 1
    plt.subplot(rows,cols,panel)
    plt.plot(data['Time'],data['HflowUMan'],linestyle='-',color=color,label=r'$Q_{UMan}$')
    plt.plot(data['Time'],data['HflowMeltMan'],linestyle=(0, (3, 5, 1, 5, 1, 5)),color=color,label=r'$Q_{Melt,Man}$')
    plt.plot(data['Time'],data['HflowCMB'],linestyle='--',color=color,label=r'$Q_{CMB}$')
    plt.plot(data['Time'],data['RadPowerMan'],linestyle=(0, (1, 5)),color=color,label=r'$Q_{Rad,Man}$')
    plt.plot(data['Time'],data['PowerEqtide'],'-.',color=color,label=r'$Q_{Tide}$')
    plt.yscale('log'); plt.xscale('log')
    plt.legend(loc='upper right',frameon=True,ncol=2,columnspacing=1)
    plt.ylabel('Power (TW)')
    plt.xlabel('Time (Gyr)')
    ymax=1e10
    plt.ylim(1e-4,ymax)
    panel += 1
    plt.subplot(rows,cols,panel)
    plt.plot(data['Time'],data['ViscUMan'],color=color)
    plt.ylabel(r'ViscUMan')
    plt.xlabel('Time (Gyr)')
    plt.xscale('log')
    plt.legend(frameon=True,loc='upper left')
    panel += 1
    plt.subplot(rows,cols,panel)
    plt.loglog(data['Time'],data['TMan'],color=color,label='TMan')
    plt.ylabel(r'TMan')
    plt.xlabel('Time (Gyr)')
    plt.yscale('log'); plt.xscale('log')
    panel += 1
    plt.subplot(rows,cols,panel)
    plt.plot(data['Time'],data['MagMom'],color=color,label='MagMom')
    plt.plot(data['Time'],data['RIC']/3481,color=color,linestyle='--')
    plt.ylim(0,1.5)
    plt.ylabel('Mag. Mom., R$_{ic}$ ($\oplus$ Units)')
    plt.xlabel('Time (Gyr)')
    plt.xscale('log')
    panel += 1
    plt.subplot(rows,cols,panel)
    plt.plot(data['Time'],data['MeltMassFluxMan']*s_yr,color=color)
    plt.ylabel(r'Melt Mass Flux Mantle (kg$/$yr)')
    plt.xlabel('Time (Gyr)')
    plt.ylim(1e12,1e18)
    plt.yscale('log'); plt.xscale('log')
plt.savefig("/Users/jcbecker/Downloads/bad_high.png", dpi=150, bbox_inches = "tight")
# Out:
# [0.01     0.064444 0.118889 0.173333 0.227778 0.282222 0.336667 0.391111
#  0.445556 0.5     ]
# [250000.       266666.666667 283333.333333 300000.       316666.666667
#  333333.333333 350000.       366666.666667 383333.333333 400000.      ]
# /Users/jcbecker/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /Users/jcbecker/anaconda3/lib/python3.7/site-packages/vplot/figure.py:354: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   self.tight_layout()
# <VPLOTFigure size 460.8x316.8 with 1 Axes>
# <VPLOTFigure size 576x864 with 0 Axes>
# <VPLOTFigure size 576x864 with 6 Axes>

# %%
plt.plot(data['Time'],data['ViscUMan'],color=color)
# Out:
# <VPLOTFigure size 460.8x316.8 with 1 Axes>
